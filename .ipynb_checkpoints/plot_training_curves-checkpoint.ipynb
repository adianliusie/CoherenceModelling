# %%
import json 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

def moving_average(x, w):
    start = np.cumsum(x[:w-1])/np.arange(1,w)
    middle = np.convolve(x, np.ones(w), 'valid') / w
    return np.concatenate((start, middle), axis=0) 

def get_lists(path):
    with open(path, 'r') as f:
        data = json.load(f)
    
    train_keys = ['tr_loss', 'tr_acc', 'tr_pos', 'tr_neg']
    train_values = zip(*data['train'])
    
    keys = ['mse', 'spear', 'mean', 'var', 'acc']
    values = [list(zip(*data['gcdc_data'][k])) for k in range(4)]

    output = dict(zip(train_keys, train_values))
    output['clinton'] = zip(keys, values[0])
    output['enron'] = zip(keys, values[1])
    output['yahoo'] = zip(keys, values[2])
    output['yelp'] = zip(keys, values[3])
    return output

# %%
path = f'/home/alta/Conversational/OET/al826/2021/coherence/results/finetuning/rob_shf_base/train_curves.json'

output = get_lists(path)

x = np.arange(1, len(output['tr_loss'])+1)
train_loss = moving_average(output['tr_loss'], 200)
train_acc = moving_average(output['tr_acc'], 200)

x_dev = 500*np.arange(1, len(output['clinton']['spear'])+1)
plt.plot(x_dev, output['clinton']['spear'])
plt.plot()

plt.xlim(0,25000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-cea299d1613d> in <module>
#       7 train_acc = moving_average(output['tr_acc'], 200)
#       8
# ----> 9 x_dev = 500*np.arange(1, len(output['clinton']['spear'])+1)
#      10 plt.plot(x_dev, output['clinton']['spear'])
#      11 plt.plot()
#
# TypeError: 'zip' object is not subscriptable

# %%
# Out:
# {'tr_loss': (0.7154242992401123, 0.7305315732955933, 0.680595874786377, 0.7198138236999512, 0.6798914074897766, 0.6723055839538574, 0.6903369426727295, 0.6942054033279419, 0.6956372857093811, 0.6923874020576477, 0.6956480145454407, 0.6907975077629089, 0.6840462684631348, 0.6946377754211426, 0.7056770324707031, 0.6875978708267212, 0.678489089012146, 0.7124317288398743, 0.7132648825645447, 0.7077744007110596, 0.6761063933372498, 0.6689773797988892, 0.693284273147583, 0.6876486539840698, 0.7033464908599854, 0.7032408714294434, 0.6915566325187683, 0.6895686388015747, 0.694064199924469, 0.6956854462623596, 0.6923631429672241, 0.6806902289390564, 0.6512709856033325, 0.717207670211792, 0.6918151378631592, 0.7200877666473389, 0.693368673324585, 0.674906313419342, 0.7327736616134644, 0.725783109664917, 0.6919127702713013, 0.6917452812194824, 0.6989321708679199, 0.7109602689743042, 0.6944156885147095, 0.6867752075195312, 0.6888699531555176, 0.6893384456634521, 0.6845192313194275, 0.6807138919830322, 0.6989948749542236, 0.6834518909454346, 0.7021610736846924, 0.6768845319747925, 0.6829700469970703, 0.6806449890136719, 0.7015770673751831, 0.6921390295028687, 0.7053320407867432, 0.6904001235961914, 0.6950193047523499, 0.6879987716674805, 0.6866422891616821, 0.6560670137405396, 0.706024169921875, 0.6965459585189819, 0.6885406970977783, 0.6899511814117432, 0.6826421022415161, 0.7064721584320068, 0.7173315286636353, 0.730600118637085, 0.6883748769760132, 0.6736360788345337, 0.6919508576393127, 0.6902496814727783, 0.6875389814376831, 0.6974474191665649, 0.6899310350418091, 0.6806700229644775, 0.692426323890686, 0.6872862577438354, 0.6770963668823242, 0.6857130527496338, 0.6882973909378052, 0.6735687255859375, 0.6864993572235107, 0.6784086227416992, 0.6855732798576355, 0.6861572265625, 0.6686335206031799, 0.6727874279022217, 0.6692972183227539, 0.6806259155273438, 0.6824694871902466, 0.6794130802154541, 0.6166961193084717, 0.6199468970298767, 0.6708835363388062, 0.6965363025665283, 0.6736202836036682, 0.6907027959823608, 0.5642017126083374, 0.6434199810028076, 0.672190248966217, 0.7939720153808594, 0.6226069331169128, 0.6477128267288208, 0.663593053817749, 0.6749387383460999, 0.6795934438705444, 0.6770743727684021, 0.6724988222122192, 0.666846513748169, 0.6294044256210327, 0.6473067998886108, 0.6241081357002258, 0.4943450093269348, 0.6510425209999084, 0.6635400056838989, 0.6950923204421997, 0.6459832191467285, 0.46816587448120117, 0.430497944355011, 0.4829971492290497, 0.5070879459381104, 0.5089951753616333, 0.5482757687568665, 0.5435248613357544, 0.5102349519729614, 0.2360953390598297, 0.24990573525428772, 0.4796988368034363, 0.4213530421257019, 0.5812380313873291, 0.3366638422012329, 0.33965423703193665, 0.4376792311668396, 0.256406307220459, 0.1474526822566986, 0.1316850185394287, 0.5016096830368042, 0.13589107990264893, 0.14420169591903687, 0.42237210273742676, 0.18742066621780396, 0.3506944477558136, 0.18367820978164673, 0.11903464794158936, 0.5164815783500671, 0.5489434003829956, 0.16721123456954956, 0.4676481783390045, 0.4220770597457886, 0.20852386951446533, 0.24932362139225006, 0.2962806820869446, 0.31075602769851685, 0.15766145288944244, 0.5721163749694824, 0.28800347447395325, 0.14724555611610413, 0.2949395775794983, 0.25941556692123413, 0.18137714266777039, 0.0575026199221611, 0.033097896724939346, 0.1806667149066925, 0.09611564874649048, 0.2225458025932312, 0.7899811267852783, 0.6501849889755249, 0.1254587471485138, 0.2242792695760727, 0.22562164068222046, 0.0826687142252922, 0.14274609088897705, 0.334542453289032, 0.3535289168357849, 0.2633346915245056, 0.16970133781433105, 0.19995073974132538, 0.21076804399490356, 0.40684741735458374, 0.2367289662361145, 0.2734922766685486, 0.2869877219200134, 0.09558325260877609, 0.2934694290161133, 0.6044526696205139, 0.5997215509414673, 0.3883194029331207, 0.050547175109386444, 0.28469860553741455, 0.020001942291855812, 0.18858185410499573, 0.050515707582235336, 0.36737704277038574, 0.33781662 ...

# %%
exp_name = 'glove_rank_long'
exp_name_2 = 'glove_wiki_rank_loss'
exp_path = get_exp_path(exp_name, base='rnd')
exp_path_2 = get_exp_path(exp_name_2)

print_curve(exp_path)
print_curve(exp_path_2)

plt.xlabel('iteration')
plt.legend(['training loss (rolling)', 'training accuracy (rolling)'])
plt.xlim(0,125_000)
# Out:
# (0.0, 125000.0)

# %%
import json

path = f'/home/alta/Conversational/OET/al826/2021/coherence/results/baseline_finetuning/rob_shf_base/train_curves.json'

with open(path, 'r') as f:
    data = json.load(f)

# %%
train_loss, train_acc, train_pos_val, train_neg_val = zip(*data['train'])

# %%
mse, spear, mean, var, acc, = zip(*data['gcdc_data'][0])

# %%
import matplotlib.pyplot as plt 
import numpy as np

def moving_average(x, w):
    start = np.cumsum(x[:w-1])/np.arange(1,w)
    middle = np.convolve(x, np.ones(w), 'valid') / w
    return np.concatenate((start, middle), axis=0) 

plt.plot(moving_average(train_loss, 200))
plt.plot(moving_average(train_pos_val, 200))
plt.plot(moving_average(train_neg_val, 200))

# %%
plt.plot(spear)
