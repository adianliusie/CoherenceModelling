# %%
from src.experiment import ExperimentHandler

# %%
from collections import namedtuple
import torch

config_dict =  {'system':'bert', 'embed_lim':100000, 'attention':False, 'hier':False,
                'bsz':6, 'lr':1e-5, 'epochs':30, 'scheduling':False, 
                'data_src':'wsj', 'c_num':1, 'schemes':[1], 'args':None, 'max_len':512,
                'debug_sz':100, 'debug':True}

ConfigTruple = namedtuple('Config', config_dict)
config = ConfigTruple(**config_dict)

E = ExperimentHandler()
E.train(config)
# Out:
# 100%|██████████| 1277/1277 [00:02<00:00, 431.85it/s]
# 0  100    0.383   0.8135
# 100%|██████████| 198/198 [00:00<00:00, 412.06it/s]
# 198   0.190   0.9091
#  ----------------------------------------------------------------------------------------------------
# 100%|██████████| 1277/1277 [00:02<00:00, 446.17it/s]
# 1  100    0.121   0.9455
# 100%|██████████| 198/198 [00:00<00:00, 412.75it/s]
# 198   0.129   0.9273
#  ----------------------------------------------------------------------------------------------------
# 100%|██████████| 1277/1277 [00:02<00:00, 449.28it/s]
# 2  100    0.073   0.9769
# 100%|██████████| 198/198 [00:00<00:00, 369.84it/s]
# 198   0.108   0.9455
#  ----------------------------------------------------------------------------------------------------
# 100%|██████████| 1277/1277 [00:02<00:00, 448.22it/s]
# 3  100    0.074   0.9686
# 100%|██████████| 198/198 [00:00<00:00, 413.14it/s]
# 198   0.131   0.9455
#  ----------------------------------------------------------------------------------------------------
# 100%|██████████| 1277/1277 [00:02<00:00, 447.65it/s]
# 4  100    0.053   0.9752
# 100%|██████████| 198/198 [00:00<00:00, 412.30it/s]
# 198   0.151   0.9182
#  ----------------------------------------------------------------------------------------------------
# 100%|██████████| 1277/1277 [00:02<00:00, 439.97it/s]
# 5  100    0.040   0.9851
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a747da0fc4ab> in <module>
#      11
#      12 E = ExperimentHandler()
# ---> 13 E.train(config)
#
# /home/alta/Conversational/OET/al826/2021/coherence/framework/src/experiment.py in train(self, config)
#      46             for k, batch in enumerate(B.make_batches(D.train, config.c_num, config.hier)):
#      47                 if config.hier:  loss, batch_acc = self.calc_batch_hier(model, batch)
# ---> 48                 else:            loss, batch_acc = self.calc_batch(model, batch)
#      49                 logger += [loss.item(), *batch_acc]
#      50
#
# /home/alta/Conversational/OET/al826/2021/coherence/framework/src/experiment.py in calc_batch(self, model, batch, no_grad)
#      89         y_neg = model(neg.ids, neg.mask)
#      90         loss = self.log_sigmoid_loss(y_pos - y_neg)
# ---> 91         acc = [sum(y_pos - y_neg > 0).item(), len(y_pos)]
#      92         return loss, acc
#
# KeyboardInterrupt:

# %%
from collections import namedtuple
import torch

config_dict =  {'system':'bert', 'embed_lim':100000, 'attention':False, 'hier':False,
                'bsz':6, 'lr':1e-5, 'epochs':30, 'scheduling':False, 
                'data_src':'wiki_small', 'c_num':1, 'schemes':[1], 'args':None, 'max_len':512,
                'debug_sz':100, 'debug':True}

ConfigTruple = namedtuple('Config', config_dict)
config = ConfigTruple(**config_dict)

E = ExperimentHandler()
E.train(config)
# Out:
# 100%|██████████| 100000/100000 [01:20<00:00, 1236.56it/s]
# 100   0.522   0.7706
# 200   0.305   0.8717
# 300   0.256   0.8983
# 400   0.214   0.9167
# 500   0.230   0.9050
# 600   0.213   0.9150
# 700   0.187   0.9267
# 800   0.173   0.9283
# 900   0.167   0.9300
# 1000  0.132   0.9483
# 1100  0.182   0.9367
# 1200  0.165   0.9333
# 1300  0.154   0.9400
# 1400  0.148   0.9417
# 1500  0.130   0.9450
# 1600  0.125   0.9483
# 1700  0.167   0.9200
# 1800  0.152   0.9400
# 1900  0.131   0.9467
# 2000  0.108   0.9517
# 2100  0.116   0.9500
# 2200  0.108   0.9517
# 2300  0.128   0.9533
# 2400  0.122   0.9483
# 2500  0.110   0.9550
# 2600  0.119   0.9617
# 2700  0.117   0.9533
# 2800  0.109   0.9567
# 2900  0.132   0.9450
# 3000  0.121   0.9600
# 3100  0.103   0.9583
# 3200  0.064   0.9767
# 3300  0.106   0.9667
# 3400  0.129   0.9567
# 3500  0.136   0.9450
# 3600  0.099   0.9600
# 3700  0.089   0.9683
# 3800  0.118   0.9567
# 3900  0.091   0.9617
# 4000  0.086   0.9700
# 4100  0.111   0.9583
# 4200  0.124   0.9583
# 4300  0.107   0.9500
# 4400  0.100   0.9717
# 4500  0.102   0.9600
# 4600  0.108   0.9633
# 4700  0.114   0.9567
# 4800  0.093   0.9683
# 4900  0.125   0.9483
# 5000  0.120   0.9550
# 5100  0.098   0.9600
# 5200  0.089   0.9683
# 5300  0.103   0.9517
# 5400  0.092   0.9583
# 5500  0.096   0.9667
# 5600  0.106   0.9583
# 5700  0.099   0.9517
# 5800  0.107   0.9550
# 5900  0.100   0.9617
# 6000  0.096   0.9667
# 6100  0.099   0.9683
# 6200  0.116   0.9583
# 6300  0.106   0.9567
# 6400  0.107   0.9550
# 6500  0.110   0.9467
# 6600  0.109   0.9583
# 6700  0.083   0.9600
# 6800  0.092   0.9617
# 6900  0.095   0.9683
# 7000  0.097   0.9633
# 7100  0.097   0.9517
# 7200  0.092   0.9633
# 7300  0.078   0.9633
# 7400  0.084   0.9633
# 7500  0.097   0.9517
# 7600  0.057   0.9800
# 7700  0.097   0.9617
# 7800  0.087   0.9683
# 7900  0.124   0.9500
# 8000  0.060   0.9750
# 8100  0.124   0.9467
# 8200  0.111   0.9683
# 8300  0.079   0.9750
# 8400  0.086   0.9683
# 8500  0.099   0.9650
# 8600  0.099   0.9700
# 8700  0.083   0.9700
# 8800  0.090   0.9650
# 8900  0.057   0.9783
# 9000  0.099   0.9633
# 9100  0.086   0.9633
# 9200  0.073   0.9717
# 9300  0.074   0.9733
# 9400  0.090   0.9683
# 9500  0.103   0.9700
# 9600  0.094   0.9633
# 9700  0.074   0.9700
# 9800  0.080   0.9683
# 9900  0.099   0.9617
# 10000 0.091   0.9650
# 10100 0.091   0.9683
# 10200 0.072   0.9667
# 10300 0.081   0.9650
# 10400 0.089   0.9600
# 10500 0.082   0.9683
# 10600 0.090   0.9717
# 10700 0.090   0.9683
# 10800 0.111   0.9517
# 10900 0.080   0.9733
# 11000 0.089   0.9683
# 11100 0.103   0.9433
# 11200 0.087   0.9617
# 11300 0.088   0.9700
# 11400 0.077   0.9683
# 11500 0.102   0.9600
# 11600 0.099   0.9583
# 11700 0.092   0.9667
# 11800 0.090   0.9650
# 11900 0.092   0.9683
# 12000 0.114   0.9567
# 12100 0.102   0.9583
# 12200 0.083   0.9633
# 12300 0.090   0.9650
# 12400 0.100   0.9650
# 12500 0.068   0.9700
# 12600 0.055   0.9800
# 12700 0.094   0.9617
# 12800 0.109   0.9567
# 12900 0.104   0.9567
# 13000 0.054   0.9817
# 13100 0.073   0.9667
# 13200 0.091   0.9617
# 13300 0.074   0.9667
# 13400 0.051   0.9800
# 13500 0.082   0.9583
# 13600 0.076   0.9717
# 13700 0.077   0.9717
# 13800 0.097   0.9617
# 13900 0.099   0.9617
# 14000 0.098   0.9633
# 14100 0.076   0.9700
# 14200 0.076   0.9667
# 14300 0.084   0.9683
# 14400 0.078   0.9717
# 14500 0.099   0.9650
# 14600 0.072   0.9700
# 14700 0.083   0.9550
# 14800 0.089   0.9683
# 14900 0.048   0.9833
# 15000 0.102   0.9500
# 15100 0.095   0.9633
# 15200 0.098   0.9567
# 15300 0.064   0.9750
# 15400 0.067   0.9717
# 15500 0.088   0.9633
# 15600 0.081   0.9767
# 15700 0.080   0.9667
# 15800 0.054   0.9750
# 15900 0.076   0.9783
# 16000 0.090   0.9633
# 16100 0.079   0.9650
# 16200 0.098   0.9517
# 16300 0.059   0.9800
# 16400 0.061   0.9783
# 16500 0.089   0.9700
# 16600 0.081   0.9650
# 100%|██████████| 39110/39110 [00:32<00:00, 1207.35it/s]
# 39110 0.078   0.9691
#  ----------------------------------------------------------------------------------------------------
# 100%|██████████| 100000/100000 [01:24<00:00, 1187.90it/s]
# 100   0.051   0.9785
# 200   0.060   0.9767
# 300   0.060   0.9750
# 400   0.039   0.9850
# 500   0.045   0.9867
# 600   0.062   0.9783
# 700   0.044   0.9817
# 800   0.043   0.9833
# 900   0.036   0.9833
# 1000  0.070   0.9683
# 1100  0.071   0.9750
# 1200  0.064   0.9750
# 1300  0.036   0.9867
# 1400  0.048   0.9833
# 1500  0.052   0.9833
# 1600  0.029   0.9883
# 1700  0.057   0.9767
# 1800  0.059   0.9783
# 1900  0.052   0.9750
# 2000  0.061   0.9733
# 2100  0.062   0.9783
# 2200  0.069   0.9767
# 2300  0.053   0.9800
# 2400  0.051   0.9817
# 2500  0.055   0.9800
# 2600  0.083   0.9633
# 2700  0.043   0.9933
# 2800  0.063   0.9783
# 2900  0.055   0.9783
# 3000  0.039   0.9800
# 3100  0.061   0.9733
# 3200  0.048   0.9817
# 3300  0.058   0.9817
# 3400  0.066   0.9733
# 3500  0.050   0.9833
# 3600  0.053   0.9833
# 3700  0.042   0.9867
# 3800  0.052   0.9783
# 3900  0.032   0.9850
# 4000  0.045   0.9850
# 4100  0.056   0.9767
# 4200  0.037   0.9900
# 4300  0.049   0.9850
# 4400  0.048   0.9817
# 4500  0.054   0.9817
# 4600  0.049   0.9800
# 4700  0.052   0.9800
# 4800  0.051   0.9817
# 4900  0.042   0.9850
# 5000  0.061   0.9750
# 5100  0.040   0.9833
# 5200  0.063   0.9750
# 5300  0.075   0.9767
# 5400  0.077   0.9717
# 5500  0.062   0.9717
# 5600  0.061   0.9733
# 5700  0.060   0.9733
# 5800  0.055   0.9717
# 5900  0.055   0.9750
# 6000  0.052   0.9750
# 6100  0.061   0.9817
# 6200  0.057   0.9767
# 6300  0.049   0.9850
# 6400  0.060   0.9817
# 6500  0.047   0.9800
# 6600  0.058   0.9750
# 6700  0.045   0.9867
# 6800  0.036   0.9867
# 6900  0.042   0.9800
# 7000  0.024   0.9883
# 7100  0.068   0.9700
# 7200  0.046   0.9883
# 7300  0.050   0.9800
# 7400  0.062   0.9717
# 7500  0.059   0.9717
# 7600  0.038   0.9867
# 7700  0.069   0.9750
# 7800  0.051   0.9850
# 7900  0.049   0.9817
# 8000  0.041   0.9850
# 8100  0.054   0.9767
# 8200  0.063   0.9783
# 8300  0.058   0.9817
# 8400  0.076   0.9700
# 8500  0.056   0.9833
# 8600  0.060   0.9817
# 8700  0.060   0.9700
# 8800  0.063   0.9767
# 8900  0.061   0.9750
# 9000  0.045   0.9783
# 9100  0.046   0.9817
# 9200  0.049   0.9800
# 9300  0.057   0.9783
# 9400  0.047   0.9833
# 9500  0.047   0.9767
# 9600  0.046   0.9833
# 9700  0.066   0.9817
# 9800  0.096   0.9633
# 9900  0.059   0.9750
# 10000 0.076   0.9717
# 10100 0.055   0.9800
# 10200 0.063   0.9717
# 10300 0.053   0.9800
# 10400 0.054   0.9750
# 10500 0.091   0.9633
# 10600 0.063   0.9717
# 10700 0.066   0.9733
# 10800 0.044   0.9867
# 10900 0.057   0.9767
# 11000 0.041   0.9767
# 11100 0.044   0.9867
# 11200 0.053   0.9800
# 11300 0.059   0.9767
# 11400 0.064   0.9733
# 11500 0.077   0.9700
# 11600 0.070   0.9717
# 11700 0.068   0.9767
# 11800 0.076   0.9733
# 11900 0.056   0.9783
# 12000 0.072   0.9783
# 12100 0.059   0.9800
# 12200 0.058   0.9767
# 12300 0.037   0.9900
# 12400 0.053   0.9817
# 12500 0.047   0.9850
# 12600 0.055   0.9767
# 12700 0.065   0.9800
# 12800 0.051   0.9867
# 12900 0.040   0.9817
# 13000 0.044   0.9817
# 13100 0.091   0.9667
# 13200 0.056   0.9833
# 13300 0.038   0.9867
# 13400 0.053   0.9783
# 13500 0.048   0.9817
# 13600 0.042   0.9783
# 13700 0.037   0.9850
# 13800 0.034   0.9883
# 13900 0.050   0.9750
# 14000 0.066   0.9717
# 14100 0.041   0.9867
# 14200 0.062   0.9733
# 14300 0.077   0.9750
# 14400 0.049   0.9817
# 14500 0.052   0.9783
# 14600 0.072   0.9800
# 14700 0.051   0.9817
# 14800 0.069   0.9750
# 14900 0.079   0.9600
# 15000 0.050   0.9850
# 15100 0.061   0.9783
# 15200 0.061   0.9767
# 15300 0.043   0.9817
# 15400 0.036   0.9833
# 15500 0.050   0.9867
# 15600 0.059   0.9717
# 15700 0.053   0.9767
# 15800 0.060   0.9800
# 15900 0.068   0.9717
# 16000 0.047   0.9817
# 16100 0.086   0.9617
# 16200 0.057   0.9750
# 16300 0.055   0.9767
# 16400 0.068   0.9717
# 16500 0.050   0.9833
# 16600 0.071   0.9717
# 100%|██████████| 39110/39110 [00:32<00:00, 1210.96it/s]
# 39110 0.076   0.9692
#  ----------------------------------------------------------------------------------------------------
# 100%|██████████| 100000/100000 [01:23<00:00, 1201.36it/s]
# 100   0.048   0.9818
# 200   0.034   0.9883
# 300   0.047   0.9817
# 400   0.029   0.9933
# 500   0.043   0.9850
# 600   0.035   0.9883
# 700   0.029   0.9850
# 800   0.052   0.9750
# 900   0.038   0.9833
# 1000  0.049   0.9833
# 1100  0.037   0.9817
# 1200  0.051   0.9833
# 1300  0.041   0.9850
# 1400  0.039   0.9817
# 1500  0.052   0.9867
# 1600  0.041   0.9867
# 1700  0.037   0.9817
# 1800  0.068   0.9717
# 1900  0.039   0.9900
# 2000  0.029   0.9917
# 2100  0.026   0.9933
# 2200  0.055   0.9850
# 2300  0.038   0.9817
# 2400  0.034   0.9867
# 2500  0.051   0.9817
# 2600  0.040   0.9867
# 2700  0.037   0.9867
# 2800  0.050   0.9800
# 2900  0.040   0.9817
# 3000  0.050   0.9833
# 3100  0.035   0.9850
# 3200  0.048   0.9867
# 3300  0.070   0.9733
# 3400  0.049   0.9817
# 3500  0.029   0.9917
# 3600  0.023   0.9917
# 3700  0.058   0.9767
# 3800  0.031   0.9933
# 3900  0.050   0.9800
# 4000  0.049   0.9783
# 4100  0.032   0.9883
# 4200  0.043   0.9800
# 4300  0.023   0.9900
# 4400  0.035   0.9917
# 4500  0.040   0.9850
# 4600  0.041   0.9850
# 4700  0.041   0.9883
# 4800  0.023   0.9917
# 4900  0.057   0.9800
# 5000  0.031   0.9867
# 5100  0.067   0.9750
# 5200  0.053   0.9750
# 5300  0.039   0.9850
# 5400  0.054   0.9800
# 5500  0.042   0.9833
# 5600  0.034   0.9867
# 5700  0.043   0.9867
# 5800  0.046   0.9900
# 5900  0.057   0.9767
# 6000  0.046   0.9833
# 6100  0.042   0.9850
# 6200  0.026   0.9900
# 6300  0.035   0.9850
# 6400  0.022   0.9917
# 6500  0.065   0.9750
# 6600  0.051   0.9800
# 6700  0.029   0.9883
# 6800  0.037   0.9850
# 6900  0.036   0.9867
# 7000  0.059   0.9767
# 7100  0.046   0.9850
# 7200  0.056   0.9783
# 7300  0.045   0.9750
# 7400  0.033   0.9883
# 7500  0.037   0.9833
# 7600  0.047   0.9850
# 7700  0.033   0.9833
# 7800  0.035   0.9833
# 7900  0.048   0.9817
# 8000  0.023   0.9950
# 8100  0.034   0.9817
# 8200  0.033   0.9867
# 8300  0.033   0.9900
# 8400  0.050   0.9883
# 8500  0.045   0.9800
# 8600  0.041   0.9833
# 8700  0.034   0.9867
# 8800  0.032   0.9867
# 8900  0.051   0.9850
# 9000  0.056   0.9833
# 9100  0.031   0.9900
# 9200  0.052   0.9800
# 9300  0.056   0.9783
# 9400  0.045   0.9833
# 9500  0.041   0.9867
# 9600  0.054   0.9767
# 9700  0.045   0.9833
# 9800  0.037   0.9850
# 9900  0.044   0.9833
# 10000 0.033   0.9850
# 10100 0.036   0.9817
# 10200 0.047   0.9867
# 10300 0.040   0.9817
# 10400 0.042   0.9833
# 10500 0.040   0.9817
# 10600 0.024   0.9950
# 10700 0.063   0.9783
# 10800 0.045   0.9817
# 10900 0.040   0.9850
# 11000 0.035   0.9833
# 11100 0.070   0.9750
# 11200 0.046   0.9850
# 11300 0.075   0.9633
# 11400 0.034   0.9883
# 11500 0.037   0.9850
# 11600 0.042   0.9850
# 11700 0.028   0.9933
# 11800 0.050   0.9750
# 11900 0.039   0.9850
# 12000 0.052   0.9817
# 12100 0.035   0.9817
# 12200 0.013   0.9983
# 12300 0.068   0.9783
# 12400 0.041   0.9867
# 12500 0.035   0.9833
# 12600 0.039   0.9833
# 12700 0.066   0.9767
# 12800 0.032   0.9883
# 12900 0.028   0.9867
# 13000 0.071   0.9700
# 13100 0.048   0.9817
# 13200 0.046   0.9833
# 13300 0.034   0.9867
# 13400 0.042   0.9833
# 13500 0.038   0.9883
# 13600 0.044   0.9800
# 13700 0.053   0.9833
# 13800 0.036   0.9883
# 13900 0.039   0.9833
# 14000 0.054   0.9750
# 14100 0.027   0.9900
# 14200 0.049   0.9800
# 14300 0.054   0.9850
# 14400 0.047   0.9800
# 14500 0.061   0.9783
# 14600 0.023   0.9967
# 14700 0.015   0.9917
# 14800 0.047   0.9850
# 14900 0.032   0.9850
# 15000 0.052   0.9750
# 15100 0.049   0.9817
# 15200 0.036   0.9933
# 15300 0.042   0.9817
# 15400 0.028   0.9883
# 15500 0.036   0.9883
# 15600 0.047   0.9783
# 15700 0.064   0.9700
# 15800 0.037   0.9850
# 15900 0.040   0.9817
# 16000 0.046   0.9817
# 16100 0.059   0.9733
# 16200 0.047   0.9800
# 16300 0.029   0.9900
# 16400 0.065   0.9750
# 16500 0.059   0.9800
# 16600 0.048   0.9883
# 100%|██████████| 39110/39110 [00:32<00:00, 1192.62it/s]
# 39110 0.073   0.9717
#  ----------------------------------------------------------------------------------------------------
# 100%|██████████| 100000/100000 [01:24<00:00, 1182.23it/s]
# 100   0.032   0.9917
# 200   0.034   0.9850
# 300   0.025   0.9933
# 400   0.031   0.9917
# 500   0.055   0.9833
# 600   0.059   0.9817
# 700   0.025   0.9917
# 800   0.029   0.9867
# 900   0.042   0.9867
# 1000  0.024   0.9900
# 1100  0.021   0.9900
# 1200  0.020   0.9950
# 1300  0.029   0.9900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d98dc24e005c> in <module>
#      11
#      12 E = ExperimentHandler()
# ---> 13 E.train(config)
#
# /home/alta/Conversational/OET/al826/2021/coherence/framework/src/experiment.py in train(self, config)
#      51                 optimizer.zero_grad()
#      52                 loss.backward()
# ---> 53                 optimizer.step()
#      54                 if config.scheduling: scheduler.step()
#      55
#
# ~/anaconda3/envs/torch1.7/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/anaconda3/envs/torch1.7/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:
