# %%
from src.experiment import ExperimentHandler
from types import SimpleNamespace

model_cfg  = {'system':'roberta', 'pooling':'first', 'hier':False, 'device':'cuda:0',
              'save':True, 'exp_name':'baseline/clinton', 'ensemble':5}

train_cfg  = {'bsz':5, 'lr':1e-5, 'epochs':5, 'scheduling':True, 'optim':'adam',
              'data_src':'clinton', 'data_lim':None, 'loss':'mse', 'max_len':512}

model_cfg  = SimpleNamespace(**model_cfg)
train_cfg  = SimpleNamespace(**train_cfg)

E = ExperimentHandler(model_cfg, None, train_cfg)
E.finetune_experiment()
# Out:
# Model Parameters:
#  namespace(device='cuda:0', ensemble=5, exp_name='baseline/clinton', hier=False, pooling='first', save=True, system='roberta')
#
#
# 1 clinton   MSE:2.76  spear:0.424  acc:0.42  mean:6.552  var:0.077
# 1 saving
#
# 2 clinton   MSE:1.72  spear:0.630  acc:0.62  mean:6.400  var:0.834
# 2 saving
#
# 3 clinton   MSE:1.64  spear:0.642  acc:0.63  mean:6.316  var:1.201
# 3 saving
#
# 4 clinton   MSE:1.68  spear:0.631  acc:0.65  mean:6.515  var:1.391
#
# 5 clinton   MSE:1.75  spear:0.624  acc:0.64  mean:6.407  var:1.461
#
# TEST (e3) clinton   MSE:1.55  spear:0.663  acc:0.57  mean:6.308  var:1.225
# TEST (e3) enron     MSE:1.75  spear:0.607  acc:0.55  mean:6.016  var:1.001
# TEST (e3) yahoo     MSE:2.76  spear:0.629  acc:0.47  mean:4.912  var:0.847
# TEST (e3) yelp      MSE:2.53  spear:0.430  acc:0.34  mean:5.449  var:0.559
#
#
# 1 clinton   MSE:2.76  spear:0.552  acc:0.51  mean:6.634  var:0.021
# 1 saving
#
# 2 clinton   MSE:1.67  spear:0.666  acc:0.63  mean:6.524  var:0.910
# 2 saving
#
# 3 clinton   MSE:1.78  spear:0.670  acc:0.65  mean:6.471  var:0.622
#
# 4 clinton   MSE:1.64  spear:0.662  acc:0.62  mean:6.517  var:1.294
# 4 saving
#
# 5 clinton   MSE:1.64  spear:0.665  acc:0.60  mean:6.426  var:1.394
# 5 saving
#
# TEST (e5) clinton   MSE:1.44  spear:0.684  acc:0.56  mean:6.436  var:1.390
# TEST (e5) enron     MSE:1.81  spear:0.587  acc:0.58  mean:6.058  var:1.237
# TEST (e5) yahoo     MSE:2.54  spear:0.693  acc:0.51  mean:4.901  var:1.201
# TEST (e5) yelp      MSE:2.20  spear:0.387  acc:0.42  mean:5.732  var:0.867
#
#
# 1 clinton   MSE:2.70  spear:0.515  acc:0.49  mean:6.944  var:0.158
# 1 saving
#
# 2 clinton   MSE:1.89  spear:0.689  acc:0.52  mean:6.047  var:0.588
# 2 saving
#
# 3 clinton   MSE:1.68  spear:0.674  acc:0.63  mean:6.152  var:1.185
# 3 saving
#
# 4 clinton   MSE:1.64  spear:0.656  acc:0.64  mean:6.457  var:1.395
# 4 saving
#
# 5 clinton   MSE:1.67  spear:0.658  acc:0.63  mean:6.508  var:1.386
#
# TEST (e4) clinton   MSE:1.53  spear:0.669  acc:0.59  mean:6.408  var:1.470
# TEST (e4) enron     MSE:1.86  spear:0.557  acc:0.56  mean:6.134  var:1.088
# TEST (e4) yahoo     MSE:2.29  spear:0.618  acc:0.48  mean:5.213  var:0.884
# TEST (e4) yelp      MSE:2.10  spear:0.415  acc:0.42  mean:5.715  var:0.674
#
#
# 1 clinton   MSE:2.36  spear:0.619  acc:0.39  mean:6.337  var:0.138
# 1 saving
#
# 2 clinton   MSE:1.89  spear:0.646  acc:0.63  mean:5.949  var:1.314
# 2 saving
#
# 3 clinton   MSE:1.69  spear:0.651  acc:0.64  mean:6.441  var:0.932
# 3 saving
#
# 4 clinton   MSE:1.91  spear:0.635  acc:0.59  mean:6.820  var:1.072
#
# 5 clinton   MSE:1.78  spear:0.634  acc:0.62  mean:6.554  var:1.430
#
# TEST (e3) clinton   MSE:1.50  spear:0.668  acc:0.58  mean:6.478  var:1.014
# TEST (e3) enron     MSE:1.76  spear:0.581  acc:0.53  mean:6.324  var:0.851
# TEST (e3) yahoo     MSE:1.86  spear:0.613  acc:0.52  mean:5.597  var:0.841
# TEST (e3) yelp      MSE:1.58  spear:0.440  acc:0.47  mean:6.159  var:0.557
#
#
# 1 clinton   MSE:3.31  spear:-0.536  acc:0.24  mean:6.573  var:0.022
# 1 saving
#
# 2 clinton   MSE:1.93  spear:0.665  acc:0.53  mean:6.188  var:0.494
# 2 saving
#
# 3 clinton   MSE:1.75  spear:0.665  acc:0.59  mean:6.590  var:0.650
# 3 saving
#
# 4 clinton   MSE:1.81  spear:0.649  acc:0.63  mean:6.079  var:1.485
#
# 5 clinton   MSE:1.62  spear:0.662  acc:0.64  mean:6.442  var:1.416
# 5 saving
#
# TEST (e5) clinton   MSE:1.47  spear:0.683  acc:0.59  mean:6.470  var:1.448
# TEST (e5) enron     MSE:1.68  spear:0.610  acc:0.56  mean:6.314  var:1.196
# TEST (e5) yahoo     MSE:2.15  spear:0.657  acc:0.49  mean:5.174  var:1.014
# TEST (e5) yelp      MSE:2.08  spear:0.409  acc:0.45  mean:5.733  var:0.823
#
#
# mean clinton   MSE:1.50  spear:0.673  acc:0.58  mean:6.420  var:1.309
# mean enron     MSE:1.77  spear:0.588  acc:0.56  mean:6.169  var:1.075
# mean yahoo     MSE:2.32  spear:0.642  acc:0.49  mean:5.159  var:0.957
# mean yelp      MSE:2.10  spear:0.416  acc:0.42  mean:5.757  var:0.696
#
# std clinton   MSE:0.04  spear:0.008  acc:0.01  mean:0.061  var:0.171
# std enron     MSE:0.06  spear:0.019  acc:0.02  mean:0.128  var:0.139
# std yahoo     MSE:0.31  spear:0.029  acc:0.02  mean:0.254  var:0.137
# std yelp      MSE:0.31  spear:0.018  acc:0.04  mean:0.228  var:0.130
#
# ensemble clinton   MSE:1.43  spear:0.687  acc:0.58  mean:6.420  var:1.243
# ensemble enron     MSE:1.67  spear:0.610  acc:0.58  mean:6.169  var:0.994
# ensemble yahoo     MSE:2.17  spear:0.673  acc:0.49  mean:5.159  var:0.872
# ensemble yelp      MSE:1.97  spear:0.431  acc:0.42  mean:5.757  var:0.621

# %%
from src.experiment import ExperimentHandler
from types import SimpleNamespace

model_cfg  = {'system':'roberta', 'pooling':'first', 'hier':False, 'device':'cuda:0',
              'save':True, 'exp_name':'baseline/enron', 'ensemble':5}

train_cfg  = {'bsz':5, 'lr':1e-5, 'epochs':5, 'scheduling':True, 'optim':'adam',
              'data_src':'enron', 'data_lim':None, 'loss':'mse', 'max_len':512}

model_cfg  = SimpleNamespace(**model_cfg)
train_cfg  = SimpleNamespace(**train_cfg)

E = ExperimentHandler(model_cfg, None, train_cfg)
E.finetune_experiment()
# Out:
# Model Parameters:
#  namespace(device='cuda:0', ensemble=5, exp_name='baseline/enron', hier=False, pooling='first', save=True, system='roberta')
#
#
# 1 enron     MSE:2.12  spear:0.423  acc:0.44  mean:6.506  var:0.204
# 1 saving
#
# 2 enron     MSE:1.70  spear:0.542  acc:0.56  mean:6.015  var:1.109
# 2 saving
#
# 3 enron     MSE:1.96  spear:0.546  acc:0.64  mean:6.663  var:1.340
#
# 4 enron     MSE:1.97  spear:0.546  acc:0.64  mean:6.434  var:1.948
#
# 5 enron     MSE:1.93  spear:0.543  acc:0.64  mean:6.340  var:1.905
#
# TEST (e2) clinton   MSE:2.05  spear:0.612  acc:0.52  mean:5.985  var:0.770
# TEST (e2) enron     MSE:1.87  spear:0.551  acc:0.49  mean:6.078  var:1.036
# TEST (e2) yahoo     MSE:3.42  spear:0.597  acc:0.42  mean:4.725  var:0.479
# TEST (e2) yelp      MSE:3.86  spear:0.435  acc:0.28  mean:4.942  var:0.363
#
#
# 1 enron     MSE:1.99  spear:0.568  acc:0.36  mean:5.744  var:0.230
# 1 saving
#
# 2 enron     MSE:1.67  spear:0.558  acc:0.54  mean:5.952  var:0.919
# 2 saving
#
# 3 enron     MSE:1.95  spear:0.543  acc:0.58  mean:6.180  var:1.862
#
# 4 enron     MSE:1.85  spear:0.555  acc:0.61  mean:6.361  var:1.616
#
# 5 enron     MSE:1.95  spear:0.551  acc:0.60  mean:6.425  var:1.763
#
# TEST (e2) clinton   MSE:2.14  spear:0.571  acc:0.45  mean:6.025  var:0.598
# TEST (e2) enron     MSE:2.00  spear:0.536  acc:0.47  mean:5.968  var:0.832
# TEST (e2) yahoo     MSE:2.97  spear:0.555  acc:0.42  mean:4.977  var:0.462
# TEST (e2) yelp      MSE:3.85  spear:0.392  acc:0.28  mean:4.967  var:0.248
#
#
# 1 enron     MSE:1.74  spear:0.488  acc:0.53  mean:6.165  var:0.624
# 1 saving
#
# 2 enron     MSE:1.71  spear:0.552  acc:0.61  mean:6.464  var:0.616
# 2 saving
#
# 3 enron     MSE:1.70  spear:0.554  acc:0.54  mean:5.971  var:1.191
# 3 saving
#
# 4 enron     MSE:1.59  spear:0.576  acc:0.58  mean:6.188  var:1.221
# 4 saving
#
# 5 enron     MSE:1.76  spear:0.568  acc:0.62  mean:6.379  var:1.652
#
# TEST (e4) clinton   MSE:1.91  spear:0.659  acc:0.52  mean:5.974  var:0.863
# TEST (e4) enron     MSE:1.77  spear:0.574  acc:0.53  mean:6.233  var:1.046
# TEST (e4) yahoo     MSE:2.37  spear:0.603  acc:0.43  mean:5.208  var:0.714
# TEST (e4) yelp      MSE:3.01  spear:0.431  acc:0.28  mean:5.240  var:0.421
#
#
# 1 enron     MSE:1.84  spear:0.482  acc:0.51  mean:5.923  var:0.888
# 1 saving
#
# 2 enron     MSE:1.64  spear:0.535  acc:0.61  mean:6.167  var:1.022
# 2 saving
#
# 3 enron     MSE:1.80  spear:0.562  acc:0.62  mean:6.333  var:1.692
#
# 4 enron     MSE:1.74  spear:0.552  acc:0.61  mean:6.163  var:1.529
#
# 5 enron     MSE:1.85  spear:0.548  acc:0.67  mean:6.371  var:1.732
#
# TEST (e2) clinton   MSE:2.11  spear:0.583  acc:0.47  mean:6.009  var:0.651
# TEST (e2) enron     MSE:1.92  spear:0.527  acc:0.49  mean:6.239  var:0.949
# TEST (e2) yahoo     MSE:2.96  spear:0.557  acc:0.42  mean:4.969  var:0.489
# TEST (e2) yelp      MSE:3.95  spear:0.375  acc:0.26  mean:4.929  var:0.272
#
#
# 1 enron     MSE:2.31  spear:0.446  acc:0.53  mean:6.822  var:0.505
# 1 saving
#
# 2 enron     MSE:2.20  spear:0.578  acc:0.50  mean:6.906  var:0.462
# 2 saving
#
# 3 enron     MSE:1.88  spear:0.595  acc:0.57  mean:6.768  var:0.811
# 3 saving
#
# 4 enron     MSE:1.85  spear:0.591  acc:0.62  mean:6.629  var:1.616
# 4 saving
#
# 5 enron     MSE:1.71  spear:0.587  acc:0.59  mean:6.332  var:1.663
# 5 saving
#
# TEST (e5) clinton   MSE:1.65  spear:0.652  acc:0.53  mean:6.297  var:1.502
# TEST (e5) enron     MSE:1.67  spear:0.624  acc:0.54  mean:6.390  var:1.460
# TEST (e5) yahoo     MSE:2.58  spear:0.573  acc:0.44  mean:5.103  var:0.987
# TEST (e5) yelp      MSE:2.76  spear:0.435  acc:0.38  mean:5.347  var:0.678
#
#
# mean clinton   MSE:1.97  spear:0.615  acc:0.50  mean:6.058  var:0.877
# mean enron     MSE:1.85  spear:0.562  acc:0.51  mean:6.182  var:1.065
# mean yahoo     MSE:2.86  spear:0.577  acc:0.43  mean:4.997  var:0.626
# mean yelp      MSE:3.49  spear:0.414  acc:0.29  mean:5.085  var:0.397
#
# std clinton   MSE:0.18  spear:0.035  acc:0.03  mean:0.121  var:0.326
# std enron     MSE:0.12  spear:0.035  acc:0.02  mean:0.145  var:0.212
# std yahoo     MSE:0.36  spear:0.020  acc:0.01  mean:0.162  var:0.203
# std yelp      MSE:0.50  spear:0.025  acc:0.04  mean:0.174  var:0.154
#
# ensemble clinton   MSE:1.88  spear:0.638  acc:0.52  mean:6.058  var:0.800
# ensemble enron     MSE:1.76  spear:0.582  acc:0.49  mean:6.182  var:0.998
# ensemble yahoo     MSE:2.77  spear:0.596  acc:0.43  mean:4.997  var:0.566
# ensemble yelp      MSE:3.41  spear:0.429  acc:0.29  mean:5.085  var:0.350

# %%
model_cfg  = {'system':'roberta', 'pooling':'first', 'hier':False, 'device':'cuda:0',
              'save':False, 'exp_name':'baseline/yahoo', 'ensemble':10}

train_cfg  = {'bsz':5, 'lr':1e-5, 'epochs':5, 'scheduling':True, 'optim':'adam',
              'data_src':'yahoo', 'data_lim':None, 'loss':'mse', 'max_len':512}

model_cfg  = SimpleNamespace(**model_cfg)
train_cfg  = SimpleNamespace(**train_cfg)

E = ExperimentHandler(model_cfg, None, train_cfg)
E.finetune_experiment()
# Out:
# Model Parameters:
#  namespace(device='cuda:0', ensemble=10, exp_name='baseline/yahoo', hier=False, pooling='first', save=False, system='roberta')
#
#
# 1 yahoo     MSE:1.97  spear:0.645  acc:0.40  mean:6.032  var:0.462
# 1 saving
#
# 2 yahoo     MSE:3.20  spear:0.630  acc:0.51  mean:4.851  var:0.280
#
# 3 yahoo     MSE:1.70  spear:0.662  acc:0.63  mean:6.023  var:1.913
# 3 saving
#
# 4 yahoo     MSE:1.81  spear:0.631  acc:0.55  mean:5.724  var:1.674
#
# 5 yahoo     MSE:1.82  spear:0.631  acc:0.55  mean:5.819  var:1.755
#
# TEST (e3) clinton   MSE:2.76  spear:0.542  acc:0.59  mean:7.416  var:0.613
# TEST (e3) enron     MSE:3.52  spear:0.492  acc:0.47  mean:7.491  var:0.540
# TEST (e3) yahoo     MSE:1.71  spear:0.657  acc:0.58  mean:6.154  var:1.942
# TEST (e3) yelp      MSE:2.11  spear:0.460  acc:0.56  mean:7.254  var:0.784
#
#
# 1 yahoo     MSE:2.49  spear:0.628  acc:0.56  mean:5.063  var:1.071
# 1 saving
#
# 2 yahoo     MSE:2.07  spear:0.653  acc:0.55  mean:5.266  var:1.067
# 2 saving
#
# 3 yahoo     MSE:1.76  spear:0.669  acc:0.60  mean:5.522  var:1.499
# 3 saving
#
# 4 yahoo     MSE:1.89  spear:0.648  acc:0.58  mean:5.498  var:1.698
#
# 5 yahoo     MSE:1.85  spear:0.636  acc:0.60  mean:5.658  var:1.817
#
# TEST (e3) clinton   MSE:2.07  spear:0.545  acc:0.58  mean:6.876  var:0.644
# TEST (e3) enron     MSE:2.41  spear:0.536  acc:0.51  mean:6.965  var:0.565
# TEST (e3) yahoo     MSE:1.62  spear:0.665  acc:0.54  mean:5.685  var:1.602
# TEST (e3) yelp      MSE:1.74  spear:0.429  acc:0.54  mean:6.895  var:0.760
#
#
# 1 yahoo     MSE:1.92  spear:0.659  acc:0.42  mean:5.898  var:0.362
# 1 saving
#
# 2 yahoo     MSE:1.76  spear:0.677  acc:0.55  mean:6.209  var:0.839
# 2 saving
#
# 3 yahoo     MSE:1.58  spear:0.687  acc:0.58  mean:5.670  var:1.062
# 3 saving
#
# 4 yahoo     MSE:1.64  spear:0.684  acc:0.63  mean:5.684  var:1.826
#
# 5 yahoo     MSE:1.66  spear:0.682  acc:0.62  mean:5.671  var:1.897
#
# TEST (e3) clinton   MSE:2.11  spear:0.494  acc:0.55  mean:6.711  var:0.413
# TEST (e3) enron     MSE:2.36  spear:0.482  acc:0.48  mean:6.797  var:0.423
# TEST (e3) yahoo     MSE:1.62  spear:0.651  acc:0.56  mean:5.790  var:1.132
# TEST (e3) yelp      MSE:1.50  spear:0.437  acc:0.54  mean:6.656  var:0.548
#
#
# 1 yahoo     MSE:1.91  spear:0.658  acc:0.47  mean:5.608  var:0.552
# 1 saving
#
# 2 yahoo     MSE:1.70  spear:0.665  acc:0.53  mean:5.826  var:0.646
# 2 saving
#
# 3 yahoo     MSE:1.70  spear:0.690  acc:0.64  mean:5.490  var:1.721
# 3 saving
#
# 4 yahoo     MSE:2.13  spear:0.657  acc:0.58  mean:5.198  var:1.485
#
# 5 yahoo     MSE:1.69  spear:0.662  acc:0.62  mean:5.732  var:1.899
# 5 saving
#
# TEST (e5) clinton   MSE:2.10  spear:0.517  acc:0.60  mean:6.920  var:0.820
# TEST (e5) enron     MSE:2.57  spear:0.484  acc:0.49  mean:7.006  var:0.796
# TEST (e5) yahoo     MSE:1.54  spear:0.680  acc:0.59  mean:5.829  var:2.002
# TEST (e5) yelp      MSE:1.92  spear:0.413  acc:0.49  mean:7.019  var:0.863
#
#
# 1 yahoo     MSE:2.26  spear:0.641  acc:0.24  mean:6.048  var:0.139
# 1 saving
#
# 2 yahoo     MSE:1.78  spear:0.670  acc:0.53  mean:5.574  var:0.709
# 2 saving
#
# 3 yahoo     MSE:1.62  spear:0.679  acc:0.57  mean:5.644  var:0.971
# 3 saving
#
# 4 yahoo     MSE:1.60  spear:0.670  acc:0.59  mean:5.803  var:1.845
# 4 saving
#
# 5 yahoo     MSE:1.76  spear:0.663  acc:0.59  mean:5.544  var:1.873
#
# TEST (e4) clinton   MSE:2.79  spear:0.565  acc:0.57  mean:7.462  var:0.496
# TEST (e4) enron     MSE:3.36  spear:0.522  acc:0.47  mean:7.438  var:0.577
# TEST (e4) yahoo     MSE:1.55  spear:0.675  acc:0.58  mean:5.946  var:1.931
# TEST (e4) yelp      MSE:1.98  spear:0.434  acc:0.53  mean:7.139  var:0.829
#
#
# 1 yahoo     MSE:1.93  spear:0.690  acc:0.39  mean:5.755  var:0.397
# 1 saving
#
# 2 yahoo     MSE:2.05  spear:0.677  acc:0.52  mean:5.242  var:1.389
#
# 3 yahoo     MSE:1.63  spear:0.687  acc:0.59  mean:5.610  var:1.281
# 3 saving
#
# 4 yahoo     MSE:1.62  spear:0.683  acc:0.61  mean:5.652  var:1.239
# 4 saving
#
# 5 yahoo     MSE:1.65  spear:0.679  acc:0.64  mean:5.734  var:1.852
#
# TEST (e4) clinton   MSE:2.04  spear:0.535  acc:0.54  mean:6.738  var:0.431
# TEST (e4) enron     MSE:2.26  spear:0.504  acc:0.51  mean:6.789  var:0.522
# TEST (e4) yahoo     MSE:1.61  spear:0.651  acc:0.57  mean:5.778  var:1.408
# TEST (e4) yelp      MSE:1.49  spear:0.489  acc:0.54  mean:6.834  var:0.604
#
#
# 1 yahoo     MSE:2.17  spear:0.624  acc:0.46  mean:6.317  var:0.428
# 1 saving
#
# 2 yahoo     MSE:2.03  spear:0.699  acc:0.54  mean:5.201  var:0.958
# 2 saving
#
# 3 yahoo     MSE:1.98  spear:0.681  acc:0.59  mean:5.244  var:1.391
# 3 saving
#
# 4 yahoo     MSE:1.62  spear:0.678  acc:0.62  mean:5.774  var:1.780
# 4 saving
#
# 5 yahoo     MSE:1.63  spear:0.673  acc:0.63  mean:5.712  var:1.777
#
# TEST (e4) clinton   MSE:2.28  spear:0.543  acc:0.57  mean:7.142  var:0.551
# TEST (e4) enron     MSE:3.09  spear:0.488  acc:0.47  mean:7.303  var:0.554
# TEST (e4) yahoo     MSE:1.62  spear:0.662  acc:0.55  mean:5.863  var:1.909
# TEST (e4) yelp      MSE:1.89  spear:0.419  acc:0.50  mean:7.015  var:0.819
#
#
# 1 yahoo     MSE:1.81  spear:0.685  acc:0.47  mean:5.880  var:0.506
# 1 saving
#
# 2 yahoo     MSE:1.72  spear:0.715  acc:0.57  mean:5.445  var:1.015
# 2 saving
#
# 3 yahoo     MSE:1.45  spear:0.709  acc:0.58  mean:5.794  var:1.451
# 3 saving
#
# 4 yahoo     MSE:1.45  spear:0.711  acc:0.61  mean:5.841  var:1.975
# 4 saving
#
# 5 yahoo     MSE:1.55  spear:0.706  acc:0.63  mean:5.598  var:1.817
#
# TEST (e4) clinton   MSE:2.69  spear:0.524  acc:0.58  mean:7.395  var:0.639
# TEST (e4) enron     MSE:3.64  spear:0.461  acc:0.47  mean:7.509  var:0.608
# TEST (e4) yahoo     MSE:1.61  spear:0.683  acc:0.59  mean:5.980  var:2.223
# TEST (e4) yelp      MSE:2.28  spear:0.397  acc:0.53  mean:7.262  var:0.940
#
#
# 1 yahoo     MSE:2.42  spear:0.626  acc:0.44  mean:6.251  var:0.744
# 1 saving
#
# 2 yahoo     MSE:1.76  spear:0.680  acc:0.56  mean:5.522  var:0.871
# 2 saving
#
# 3 yahoo     MSE:1.69  spear:0.670  acc:0.60  mean:5.607  var:1.299
# 3 saving
#
# 4 yahoo     MSE:1.71  spear:0.646  acc:0.58  mean:5.994  var:1.542
#
# 5 yahoo     MSE:1.81  spear:0.640  acc:0.58  mean:5.685  var:1.749
#
# TEST (e3) clinton   MSE:2.09  spear:0.524  acc:0.57  mean:6.795  var:0.542
# TEST (e3) enron     MSE:2.31  spear:0.507  acc:0.51  mean:6.826  var:0.511
# TEST (e3) yahoo     MSE:1.63  spear:0.655  acc:0.59  mean:5.761  var:1.391
# TEST (e3) yelp      MSE:1.61  spear:0.420  acc:0.56  mean:6.813  var:0.548
#
#
# 1 yahoo     MSE:3.12  spear:0.625  acc:0.51  mean:4.774  var:0.690
# 1 saving
#
# 2 yahoo     MSE:1.76  spear:0.706  acc:0.51  mean:6.297  var:0.906
# 2 saving
#
# 3 yahoo     MSE:1.60  spear:0.692  acc:0.55  mean:6.155  var:1.349
# 3 saving
#
# 4 yahoo     MSE:1.57  spear:0.683  acc:0.60  mean:5.825  var:1.689
# 4 saving
#
# 5 yahoo     MSE:1.74  spear:0.671  acc:0.62  mean:5.578  var:1.792
#
# TEST (e4) clinton   MSE:2.56  spear:0.533  acc:0.58  mean:7.320  var:0.598
# TEST (e4) enron     MSE:2.99  spear:0.544  acc:0.48  mean:7.309  var:0.608
# TEST (e4) yahoo     MSE:1.52  spear:0.676  acc:0.59  mean:5.969  var:1.772
# TEST (e4) yelp      MSE:2.04  spear:0.447  acc:0.54  mean:7.222  var:0.724
#
#
# mean clinton   MSE:2.35  spear:0.532  acc:0.57  mean:7.077  var:0.575
# mean enron     MSE:2.85  spear:0.502  acc:0.48  mean:7.143  var:0.571
# mean yahoo     MSE:1.61  spear:0.666  acc:0.58  mean:5.876  var:1.731
# mean yelp      MSE:1.86  spear:0.434  acc:0.53  mean:7.011  var:0.742
#
# std clinton   MSE:0.30  spear:0.018  acc:0.02  mean:0.287  var:0.112
# std enron     MSE:0.51  spear:0.025  acc:0.02  mean:0.281  var:0.091
# std yahoo     MSE:0.05  spear:0.012  acc:0.02  mean:0.131  var:0.321
# std yelp      MSE:0.25  spear:0.025  acc:0.02  mean:0.198  var:0.128
#
# ensemble clinton   MSE:2.22  spear:0.559  acc:0.58  mean:7.077  var:0.525
# ensemble enron     MSE:2.73  spear:0.529  acc:0.48  mean:7.143  var:0.527
# ensemble yahoo     MSE:1.51  spear:0.677  acc:0.56  mean:5.876  var:1.654
# ensemble yelp      MSE:1.77  spear:0.447  acc:0.53  mean:7.011  var:0.689

# %%
model_cfg  = {'system':'roberta', 'pooling':'first', 'hier':False, 'device':'cuda:0',
              'save':False, 'exp_name':'baseline/yelp', 'ensemble':10}

train_cfg  = {'bsz':5, 'lr':1e-5, 'epochs':5, 'scheduling':True, 'optim':'adam',
              'data_src':'yelp', 'data_lim':None, 'loss':'mse', 'max_len':512}

model_cfg  = SimpleNamespace(**model_cfg)
train_cfg  = SimpleNamespace(**train_cfg)

E = ExperimentHandler(model_cfg, None, train_cfg)
E.finetune_experiment()
# Out:
# Model Parameters:
#  namespace(device='cuda:0', ensemble=10, exp_name='baseline/yelp', hier=False, pooling='first', save=False, system='roberta')
#
#
# 1 yelp      MSE:2.09  spear:0.456  acc:0.24  mean:6.170  var:0.103
# 1 saving
#
# 2 yelp      MSE:1.65  spear:0.525  acc:0.63  mean:6.649  var:0.385
# 2 saving
#
# 3 yelp      MSE:1.54  spear:0.554  acc:0.64  mean:6.596  var:0.650
# 3 saving
#
# 4 yelp      MSE:1.49  spear:0.555  acc:0.64  mean:6.538  var:0.895
# 4 saving
#
# 5 yelp      MSE:1.52  spear:0.570  acc:0.61  mean:6.430  var:1.027
#
# TEST (e4) clinton   MSE:1.99  spear:0.600  acc:0.47  mean:6.132  var:0.533
# TEST (e4) enron     MSE:2.18  spear:0.441  acc:0.41  mean:6.133  var:0.499
# TEST (e4) yahoo     MSE:2.03  spear:0.598  acc:0.49  mean:5.483  var:0.900
# TEST (e4) yelp      MSE:1.48  spear:0.455  acc:0.52  mean:6.645  var:0.735
#
#
# 1 yelp      MSE:1.94  spear:0.430  acc:0.54  mean:6.597  var:0.160
# 1 saving
#
# 2 yelp      MSE:1.62  spear:0.537  acc:0.64  mean:6.491  var:0.489
# 2 saving
#
# 3 yelp      MSE:1.63  spear:0.505  acc:0.56  mean:6.573  var:0.563
#
# 4 yelp      MSE:1.66  spear:0.547  acc:0.58  mean:6.268  var:0.932
#
# 5 yelp      MSE:1.64  spear:0.550  acc:0.59  mean:6.319  var:1.063
#
# TEST (e2) clinton   MSE:2.10  spear:0.533  acc:0.46  mean:6.305  var:0.271
# TEST (e2) enron     MSE:2.18  spear:0.463  acc:0.43  mean:6.202  var:0.310
# TEST (e2) yahoo     MSE:1.94  spear:0.591  acc:0.48  mean:5.693  var:0.672
# TEST (e2) yelp      MSE:1.43  spear:0.464  acc:0.55  mean:6.598  var:0.417
#
#
# 1 yelp      MSE:2.68  spear:0.159  acc:0.20  mean:5.952  var:0.020
# 1 saving
#
# 2 yelp      MSE:1.92  spear:0.489  acc:0.48  mean:6.386  var:0.138
# 2 saving
#
# 3 yelp      MSE:1.52  spear:0.526  acc:0.63  mean:6.545  var:0.671
# 3 saving
#
# 4 yelp      MSE:1.48  spear:0.551  acc:0.61  mean:6.642  var:0.831
# 4 saving
#
# 5 yelp      MSE:1.50  spear:0.542  acc:0.63  mean:6.454  var:1.050
#
# TEST (e4) clinton   MSE:2.51  spear:0.575  acc:0.39  mean:5.702  var:0.778
# TEST (e4) enron     MSE:2.47  spear:0.445  acc:0.44  mean:5.726  var:0.670
# TEST (e4) yahoo     MSE:2.14  spear:0.631  acc:0.51  mean:5.280  var:1.097
# TEST (e4) yelp      MSE:1.45  spear:0.479  acc:0.53  mean:6.742  var:0.653
#
#
# 1 yelp      MSE:2.25  spear:0.440  acc:0.23  mean:6.009  var:0.120
# 1 saving
#
# 2 yelp      MSE:1.78  spear:0.520  acc:0.47  mean:6.183  var:0.424
# 2 saving
#
# 3 yelp      MSE:1.67  spear:0.559  acc:0.51  mean:6.149  var:0.753
# 3 saving
#
# 4 yelp      MSE:1.49  spear:0.593  acc:0.60  mean:6.344  var:0.967
# 4 saving
#
# 5 yelp      MSE:1.44  spear:0.592  acc:0.61  mean:6.484  var:1.056
# 5 saving
#
# TEST (e5) clinton   MSE:3.06  spear:0.568  acc:0.39  mean:5.458  var:0.961
# TEST (e5) enron     MSE:2.82  spear:0.433  acc:0.41  mean:5.492  var:0.725
# TEST (e5) yahoo     MSE:3.01  spear:0.639  acc:0.47  mean:4.783  var:1.194
# TEST (e5) yelp      MSE:1.47  spear:0.463  acc:0.57  mean:6.596  var:0.937
#
#
# 1 yelp      MSE:2.02  spear:0.370  acc:0.25  mean:6.358  var:0.129
# 1 saving
#
# 2 yelp      MSE:1.63  spear:0.522  acc:0.56  mean:6.449  var:0.376
# 2 saving
#
# 3 yelp      MSE:1.79  spear:0.560  acc:0.45  mean:5.984  var:0.706
#
# 4 yelp      MSE:1.89  spear:0.576  acc:0.52  mean:5.891  var:1.119
#
# 5 yelp      MSE:1.48  spear:0.595  acc:0.55  mean:6.257  var:1.075
# 5 saving
#
# TEST (e5) clinton   MSE:4.91  spear:0.590  acc:0.28  mean:4.793  var:0.827
# TEST (e5) enron     MSE:4.42  spear:0.382  acc:0.35  mean:4.820  var:0.648
# TEST (e5) yahoo     MSE:4.24  spear:0.596  acc:0.42  mean:4.373  var:0.933
# TEST (e5) yelp      MSE:1.49  spear:0.465  acc:0.52  mean:6.375  var:1.002
#
#
# 1 yelp      MSE:2.35  spear:0.365  acc:0.20  mean:6.426  var:0.003
# 1 saving
#
# 2 yelp      MSE:1.89  spear:0.423  acc:0.47  mean:6.790  var:0.273
# 2 saving
#
# 3 yelp      MSE:1.96  spear:0.473  acc:0.52  mean:6.081  var:0.682
#
# 4 yelp      MSE:1.82  spear:0.493  acc:0.57  mean:6.277  var:1.070
# 4 saving
#
# 5 yelp      MSE:1.79  spear:0.496  acc:0.58  mean:6.328  var:1.064
# 5 saving
#
# TEST (e5) clinton   MSE:4.25  spear:0.533  acc:0.27  mean:5.064  var:0.667
# TEST (e5) enron     MSE:3.68  spear:0.333  acc:0.39  mean:5.168  var:0.727
# TEST (e5) yahoo     MSE:2.44  spear:0.569  acc:0.47  mean:5.228  var:0.910
# TEST (e5) yelp      MSE:1.58  spear:0.428  acc:0.52  mean:6.496  var:0.905
#
#
# 1 yelp      MSE:1.91  spear:0.414  acc:0.46  mean:6.472  var:0.192
# 1 saving
#
# 2 yelp      MSE:1.67  spear:0.568  acc:0.53  mean:6.268  var:0.410
# 2 saving
#
# 3 yelp      MSE:1.61  spear:0.540  acc:0.56  mean:6.306  var:0.759
# 3 saving
#
# 4 yelp      MSE:1.53  spear:0.568  acc:0.63  mean:6.698  var:0.912
# 4 saving
#
# 5 yelp      MSE:1.53  spear:0.575  acc:0.59  mean:6.379  var:1.086
#
# TEST (e4) clinton   MSE:2.22  spear:0.575  acc:0.43  mean:5.916  var:0.745
# TEST (e4) enron     MSE:2.59  spear:0.399  acc:0.42  mean:5.727  var:0.694
# TEST (e4) yahoo     MSE:2.11  spear:0.655  acc:0.52  mean:5.239  var:1.161
# TEST (e4) yelp      MSE:1.53  spear:0.462  acc:0.53  mean:6.794  var:0.766
#
#
# 1 yelp      MSE:2.09  spear:0.452  acc:0.37  mean:6.410  var:0.052
# 1 saving
#
# 2 yelp      MSE:1.73  spear:0.487  acc:0.57  mean:6.468  var:0.283
# 2 saving
#
# 3 yelp      MSE:1.68  spear:0.528  acc:0.60  mean:6.258  var:0.642
# 3 saving
#
# 4 yelp      MSE:1.86  spear:0.520  acc:0.57  mean:6.073  var:1.013
#
# 5 yelp      MSE:1.69  spear:0.524  acc:0.58  mean:6.305  var:1.094
#
# TEST (e3) clinton   MSE:3.27  spear:0.511  acc:0.29  mean:5.422  var:0.482
# TEST (e3) enron     MSE:2.71  spear:0.454  acc:0.39  mean:5.536  var:0.369
# TEST (e3) yahoo     MSE:2.61  spear:0.596  acc:0.40  mean:5.076  var:0.628
# TEST (e3) yelp      MSE:1.44  spear:0.439  acc:0.52  mean:6.389  var:0.599
#
#
# 1 yelp      MSE:2.11  spear:0.445  acc:0.55  mean:6.729  var:0.049
# 1 saving
#
# 2 yelp      MSE:1.93  spear:0.434  acc:0.57  mean:6.854  var:0.223
# 2 saving
#
# 3 yelp      MSE:1.62  spear:0.549  acc:0.58  mean:6.754  var:0.532
# 3 saving
#
# 4 yelp      MSE:1.67  spear:0.546  acc:0.55  mean:6.186  var:0.888
#
# 5 yelp      MSE:1.58  spear:0.543  acc:0.56  mean:6.367  var:1.065
# 5 saving
#
# TEST (e5) clinton   MSE:3.15  spear:0.551  acc:0.39  mean:5.458  var:0.829
# TEST (e5) enron     MSE:2.98  spear:0.436  acc:0.42  mean:5.409  var:0.725
# TEST (e5) yahoo     MSE:2.27  spear:0.603  acc:0.49  mean:5.275  var:0.927
# TEST (e5) yelp      MSE:1.50  spear:0.440  acc:0.49  mean:6.478  var:0.903
#
#
# 1 yelp      MSE:1.83  spear:0.407  acc:0.60  mean:6.572  var:0.265
# 1 saving
#
# 2 yelp      MSE:1.75  spear:0.500  acc:0.58  mean:6.202  var:0.585
# 2 saving
#
# 3 yelp      MSE:1.61  spear:0.552  acc:0.56  mean:6.159  var:1.046
# 3 saving
#
# 4 yelp      MSE:1.84  spear:0.561  acc:0.56  mean:5.954  var:1.186
#
# 5 yelp      MSE:1.47  spear:0.566  acc:0.57  mean:6.444  var:1.221
# 5 saving
#
# TEST (e5) clinton   MSE:3.76  spear:0.537  acc:0.34  mean:5.211  var:0.911
# TEST (e5) enron     MSE:3.52  spear:0.427  acc:0.41  mean:5.150  var:0.812
# TEST (e5) yahoo     MSE:3.01  spear:0.670  acc:0.45  mean:4.733  var:1.123
# TEST (e5) yelp      MSE:1.47  spear:0.498  acc:0.53  mean:6.554  var:0.959
#
#
# mean clinton   MSE:3.12  spear:0.557  acc:0.37  mean:5.546  var:0.701
# mean enron     MSE:2.95  spear:0.421  acc:0.41  mean:5.536  var:0.618
# mean yahoo     MSE:2.58  spear:0.615  acc:0.47  mean:5.116  var:0.955
# mean yelp      MSE:1.48  spear:0.460  acc:0.53  mean:6.567  var:0.788
#
# std clinton   MSE:0.92  spear:0.027  acc:0.07  mean:0.450  var:0.203
# std enron     MSE:0.68  spear:0.037  acc:0.02  mean:0.411  var:0.159
# std yahoo     MSE:0.66  spear:0.030  acc:0.04  mean:0.369  var:0.185
# std yelp      MSE:0.04  spear:0.019  acc:0.02  mean:0.131  var:0.179
#
# ensemble clinton   MSE:2.81  spear:0.600  acc:0.32  mean:5.546  var:0.590
# ensemble enron     MSE:2.69  spear:0.444  acc:0.42  mean:5.536  var:0.526
# ensemble yahoo     MSE:2.33  spear:0.656  acc:0.47  mean:5.116  var:0.839
# ensemble yelp      MSE:1.39  spear:0.472  acc:0.53  mean:6.567  var:0.713

# %%
from src.experiment import ExperimentHandler
from types import SimpleNamespace

model_cfg  = {'system':'roberta', 'pooling':'first', 'hier':False, 'device':'cuda:0',
              'save':False, 'exp_name':'baseline/clinton', 'ensemble':5}

train_cfg  = {'bsz':5, 'lr':1e-5, 'epochs':5, 'scheduling':True, 'optim':'adam',
              'data_src':'clinton', 'data_lim':None, 'loss':'mse', 'max_len':512}

model_cfg  = SimpleNamespace(**model_cfg)
train_cfg  = SimpleNamespace(**train_cfg)

E = ExperimentHandler(model_cfg, None, train_cfg)
E.finetune_experiment()
# Out:
# Model Parameters:
#  namespace(device='cuda:0', ensemble=5, exp_name='baseline/clinton', hier=False, pooling='first', save=False, system='roberta')
#
#
# 1 clinton   MSE:2.27  spear:0.626  acc:0.42  mean:6.332  var:0.202
# 1 saving
#
# 2 clinton   MSE:1.80  spear:0.706  acc:0.57  mean:6.585  var:0.512
# 2 saving
#
# 3 clinton   MSE:1.61  spear:0.713  acc:0.62  mean:6.706  var:0.906
# 3 saving
#
# 4 clinton   MSE:1.58  spear:0.675  acc:0.67  mean:6.507  var:1.291
# 4 saving
#
# 5 clinton   MSE:1.56  spear:0.687  acc:0.64  mean:6.539  var:1.285
# 5 saving
#
# TEST (e5) clinton   MSE:1.38  spear:0.693  acc:0.61  mean:6.491  var:1.470
# TEST (e5) enron     MSE:1.93  spear:0.570  acc:0.57  mean:6.035  var:1.293
# TEST (e5) yahoo     MSE:2.29  spear:0.664  acc:0.49  mean:5.067  var:1.231
# TEST (e5) yelp      MSE:1.58  spear:0.443  acc:0.46  mean:6.178  var:0.781
#
#
# 1 clinton   MSE:2.56  spear:0.626  acc:0.36  mean:5.808  var:0.228
# 1 saving
#
# 2 clinton   MSE:2.68  spear:0.638  acc:0.39  mean:5.691  var:0.253
#
# 3 clinton   MSE:1.67  spear:0.646  acc:0.61  mean:6.409  var:0.933
# 3 saving
#
# 4 clinton   MSE:1.78  spear:0.632  acc:0.64  mean:6.214  var:1.345
#
# 5 clinton   MSE:1.78  spear:0.616  acc:0.62  mean:6.448  var:1.474
#
# TEST (e3) clinton   MSE:1.45  spear:0.691  acc:0.62  mean:6.448  var:0.918
# TEST (e3) enron     MSE:1.73  spear:0.601  acc:0.56  mean:6.295  var:0.669
# TEST (e3) yahoo     MSE:1.86  spear:0.636  acc:0.47  mean:5.670  var:0.558
# TEST (e3) yelp      MSE:1.81  spear:0.453  acc:0.41  mean:5.847  var:0.397
#
#
# 1 clinton   MSE:2.84  spear:0.505  acc:0.42  mean:6.547  var:0.014
# 1 saving
#
# 2 clinton   MSE:1.92  spear:0.690  acc:0.54  mean:6.351  var:0.345
# 2 saving
#
# 3 clinton   MSE:1.77  spear:0.664  acc:0.59  mean:6.784  var:0.901
# 3 saving
#
# 4 clinton   MSE:1.55  spear:0.686  acc:0.66  mean:6.297  var:1.316
# 4 saving
#
# 5 clinton   MSE:1.57  spear:0.677  acc:0.64  mean:6.443  var:1.382
#
# TEST (e4) clinton   MSE:1.49  spear:0.684  acc:0.56  mean:6.334  var:1.395
# TEST (e4) enron     MSE:1.72  spear:0.593  acc:0.55  mean:6.128  var:1.095
# TEST (e4) yahoo     MSE:2.28  spear:0.636  acc:0.47  mean:5.184  var:0.761
# TEST (e4) yelp      MSE:2.50  spear:0.433  acc:0.35  mean:5.477  var:0.638
#
#
# 1 clinton   MSE:2.57  spear:0.513  acc:0.29  mean:6.119  var:0.124
# 1 saving
#
# 2 clinton   MSE:2.88  spear:0.614  acc:0.51  mean:7.182  var:0.132
#
# 3 clinton   MSE:1.80  spear:0.616  acc:0.57  mean:6.646  var:0.805
# 3 saving
#
# 4 clinton   MSE:1.76  spear:0.625  acc:0.60  mean:6.329  var:1.023
# 4 saving
#
# 5 clinton   MSE:1.74  spear:0.619  acc:0.61  mean:6.537  var:1.215
# 5 saving
#
# TEST (e5) clinton   MSE:1.57  spear:0.651  acc:0.65  mean:6.549  var:1.317
# TEST (e5) enron     MSE:1.74  spear:0.602  acc:0.53  mean:6.376  var:0.984
# TEST (e5) yahoo     MSE:2.21  spear:0.639  acc:0.45  mean:5.218  var:0.958
# TEST (e5) yelp      MSE:1.70  spear:0.501  acc:0.42  mean:5.888  var:0.726
#
#
# 1 clinton   MSE:2.81  spear:0.538  acc:0.51  mean:6.984  var:0.094
# 1 saving
#
# 2 clinton   MSE:1.77  spear:0.662  acc:0.62  mean:6.689  var:0.884
# 2 saving
#
# 3 clinton   MSE:1.69  spear:0.657  acc:0.61  mean:6.493  var:1.122
# 3 saving
#
# 4 clinton   MSE:1.69  spear:0.649  acc:0.59  mean:6.589  var:1.324
#
# 5 clinton   MSE:1.71  spear:0.638  acc:0.56  mean:6.483  var:1.394
#
# TEST (e3) clinton   MSE:1.44  spear:0.680  acc:0.61  mean:6.559  var:1.160
# TEST (e3) enron     MSE:1.66  spear:0.609  acc:0.54  mean:6.355  var:0.942
# TEST (e3) yahoo     MSE:1.96  spear:0.637  acc:0.49  mean:5.404  var:1.021
# TEST (e3) yelp      MSE:1.76  spear:0.440  acc:0.44  mean:5.971  var:0.788
#
#
# mean clinton   MSE:1.47  spear:0.680  acc:0.61  mean:6.476  var:1.252
# mean enron     MSE:1.76  spear:0.595  acc:0.55  mean:6.238  var:0.997
# mean yahoo     MSE:2.12  spear:0.642  acc:0.47  mean:5.308  var:0.906
# mean yelp      MSE:1.87  spear:0.454  acc:0.42  mean:5.872  var:0.666
#
# std clinton   MSE:0.07  spear:0.015  acc:0.03  mean:0.082  var:0.196
# std enron     MSE:0.09  spear:0.013  acc:0.02  mean:0.133  var:0.204
# std yahoo     MSE:0.18  spear:0.011  acc:0.02  mean:0.210  var:0.230
# std yelp      MSE:0.32  spear:0.024  acc:0.04  mean:0.228  var:0.145
#
# ensemble clinton   MSE:1.38  spear:0.700  acc:0.61  mean:6.476  var:1.174
# ensemble enron     MSE:1.65  spear:0.618  acc:0.56  mean:6.238  var:0.910
# ensemble yahoo     MSE:1.97  spear:0.676  acc:0.47  mean:5.308  var:0.799
# ensemble yelp      MSE:1.73  spear:0.479  acc:0.45  mean:5.872  var:0.580
